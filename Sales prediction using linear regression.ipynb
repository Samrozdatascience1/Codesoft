# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv("G:\/advertising.csv")

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df.isnull().sum()/len(df)*100
# Out:
# TV           0.0
# Radio        0.0
# Newspaper    0.0
# Sales        0.0
# dtype: float64

# %%
plt.xlabel("Advertising spent on Tv ADS")
plt.ylabel("Sales")
plt.title("Money spent on Advertising vs Sales")
plt.scatter(df.TV,df.Sales)

# %%
plt.xlabel("Advertising spent on Newspaper")
plt.ylabel("Sales")
plt.title("Money spent on Advertising vs Sales")
plt.scatter(df.Newspaper,df.Sales)

# %%
plt.xlabel("Advertising spent on Radio")
plt.ylabel("Sales")
plt.title("Money spent on Advertising vs Sales")
plt.scatter(df.Radio,df.Sales)

# %%
x=df.drop(columns="Sales",axis=1)
y=df.Sales

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
#         TV  Radio  Newspaper
# 134   36.9   38.6       65.6
# 66    31.5   24.6        2.2
# 26   142.9   29.3       12.6
# 113  209.6   20.6       10.7
# 168  215.4   23.6       57.6
# ..     ...    ...        ...
# 67   139.3   14.5       10.2
# 192   17.2    4.1       31.6
# 117   76.4    0.8       14.8
# 47   239.9   41.5       18.5
# 172   19.6   20.1       17.0
#
# [160 rows x 3 columns]

# %%
x_test
# Out:
#         TV  Radio  Newspaper
# 18    69.2   20.5       18.3
# 170   50.0   11.6       18.4
# 107   90.4    0.3       23.2
# 98   289.7   42.3       51.2
# 177  170.2    7.8       35.2
# 182   56.2    5.7       29.7
# 5      8.7   48.9       75.0
# 146  240.1    7.3        8.7
# 12    23.8   35.1       65.9
# 152  197.6   23.3       14.2
# 61   261.3   42.7       54.7
# 125   87.2   11.8       25.9
# 180  156.6    2.6        8.3
# 154  187.8   21.1        9.5
# 80    76.4   26.7       22.3
# 7    120.2   19.6       11.6
# 33   265.6   20.0        0.3
# 130    0.7   39.6        8.7
# 37    74.7   49.4       45.7
# 74   213.4   24.6       13.1
# 183  287.6   43.0       71.8
# 145  140.3    1.9        9.0
# 45   175.1   22.5       31.5
# 159  131.7   18.4       34.6
# 60    53.5    2.0       21.4
# 123  123.1   34.6       12.4
# 179  165.6   10.0       17.6
# 185  205.0   45.1       19.6
# 122  224.0    2.4       15.6
# 44    25.1   25.7       43.3
# 16    67.8   36.6      114.0
# ...

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression().fit(x_train,y_train)

# %%
y_predict=model.predict(x_test)

# %%
y_predict
# Out:
# array([10.70988945,  8.68629773,  9.5778695 , 24.86207988, 14.65584473,
#         8.3214275 , 10.43048002, 18.4453765 ,  9.73394291, 17.9290798 ,
#        23.369886  , 10.67916356, 13.44032325, 17.17416235, 11.77380187,
#        13.37072678, 21.26009906,  9.19666875, 14.13201846, 18.9260716 ,
#        24.75507991, 12.48481182, 16.57130583, 13.77344772,  7.79299106,
#        15.19648316, 14.71607944, 20.73862119, 17.01041859,  8.83474391,
#        12.09424377, 20.74886454, 21.26147987, 21.90420095,  7.08087067,
#         7.04431681,  9.15949871, 15.47796148, 13.28282334,  7.23769883])

# %%
y_test
# Out:
# 18     11.3
# 170     8.4
# 107    12.0
# 98     25.4
# 177    16.7
# 182     8.7
# 5       7.2
# 146    18.2
# 12      9.2
# 152    16.6
# 61     24.2
# 125    10.6
# 180    15.5
# 154    20.6
# 80     11.8
# 7      13.2
# 33     17.4
# 130     1.6
# 37     14.7
# 74     17.0
# 183    26.2
# 145    10.3
# 45     16.1
# 159    12.9
# 60      8.1
# 123    15.2
# 179    17.6
# 185    22.6
# 122    16.6
# 44      8.5
# 16     12.5
# 55     23.7
# 150    16.1
# 111    21.8
# 22      5.6
# 189     6.7
# 129     9.7
# 4      17.9
# 83     13.6
# 106     7.2
# Name: Sales, dtype: float64

# %%
model.score(x_test,y_test)
# Out:
# 0.8645053923967725

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression().fit(x,y)

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
model.predict([[230,37,69]])
# Out:
# c:\Users\Samroz\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([21.1298594])
